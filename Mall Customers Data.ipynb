# %% [markdown]
# # <center>        **Introduction to Data Science (S1-22_DSECLZG532)-ASSIGNMENT**</center>
#
# ## Group No 19
#
# ## Group Member Names:
# 1. SURYA K
# 2. SENTHIL KUMAR K
# 3. LAKSHMANAPERUMAL K
# 4. SUBBU K

# %% [markdown]
# # 1. Business Understanding
#
# Students are expected to identify a classification problem of your choice. You have to detail the Business Understanding part of your problem under this heading which basically addresses the following questions.
#
#    1. What is the business problem that you are trying to solve?
#    2. What data do you need to answer the above problem?
#    3. What are the different sources of data?
#    4. What kind of analytics task are you performing?
#
# Score: 1 Mark in total (0.25 mark each)

# %% [markdown]
# ##--------------Type the answers below this line-------------- ##
#
# 1. What is the business problem that you are trying to solve?
#
#     We are owing a supermarket mall and through membership cards , we have some basic data about our customers like Customer ID, age, gender, annual income and spending score.
# Spending Score is something we assign to the customer based on our defined parameters like customer behavior and purchasing data. We want to understand the customers like who can be easily converge [Target Customers] so that the sense can be given to marketing team and plan the strategy accordingly.
#
#     a. We are trying to analyze the factors on which spending levels of the customers visiting the mall depends on
#     b. Based on results of analysis, we need to build strategies for different segments of customers.
#
#
# 2.  What data do you need to answer the above problem?
#     Basic customer information to understand the customer spending pattern like Customer.
#     The data requires the following features:
#     a. Customer ID
#     b. Customer Gender
#     c. Customer Age
#     d. Annual Income of the customer (in Thousand Dollars)
#     5. Spending score of the customer (based on customer behaviour and spending nature)
#
#     The data has 200 entries, that is data from 200 customers.
#
# 3. What are the different sources of data?
#
#     We could find appropriate data from Kaggle.com which provides the metrics we are looking for.
#     This data was available here " https://www.kaggle.com/datasets/shwetabh123/mall-customers "
#     For the direct input into the file, we have stored this information at below location :
#     https://raw.githubusercontent.com/jbos9/mallcustomer/main/Mall_Customers.csv
#
# 4. What kind of analytics task are you performing?
#     a.Download the data set and loading it into a data frame
#     b.understanding cutomer data size and data types - numerical, categorical or text
#     c.data preparation/ cleanup by identifying duplicate, null or inconsistent values.
#     d.encoding non-numerical categorical to numerical data type for machine learning model
#     e.Feature and Label(Target) identification
#     f.Data visualization
#     g.Findout dependency of Overall Rating on various matrics
#     h.Identify top 5 features for creating ML model
#     i.Implement ML algorithms

# %% [markdown]
# # 2. Data Acquisition
#
# For the problem identified , find an appropriate data set (Your data set must
# be unique) from any public data source.
#
# ---
#
#
#
# ## 2.1 Download the data directly

# %%
##---------Type the code below this line------------------##

import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PowerTransformer
#from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
## 2.1 Download the data directly

url = 'https://raw.githubusercontent.com/jbos9/mallcustomer/main/Mall_Customers.csv'

## 2.2 Code for converting the above downloaded data into a dataframe

df = pd.read_csv(url)

df.shape
# Out:
# (200, 5)

# %% [markdown]
# ## 2.2 Code for converting the above downloaded data into a dataframe

# %%
##---------Type the code below this line------------------##

# %% [markdown]
# ## 2.3 Confirm the data has been correctly by displaying the first 5 and last 5 records.

# %% [markdown]
# ## 2.4 Display the column headings, statistical information, description and statistical summary of the data.

# %%
##---------Type the code below this line------------------##
print(df.head())
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
##---------Type the code below this line------------------##
print(df.tail())
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
##--------------Type the answers below this line--------------
df.shape
# Out:
# (200, 5)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
print(df.describe())
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.info()


## 2.4 Display the column headings, statistical information, description and statistical summary of the data.

print ("\n")
categorical = df.select_dtypes(["object"]).columns
for cat_col in categorical:
    print(f"{cat_col} : is a Categorical column")
    
print ("\n")   
numeric = df.select_dtypes(["int", "float"]).columns
for num_col in numeric:
    print(f"{num_col} : is a Numerical column")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
#
#
# Genre : is a Categorical column
#
#
# CustomerID : is a Numerical column
# Age : is a Numerical column
# Annual Income (k$) : is a Numerical column
# Spending Score (1-100) : is a Numerical column

# %% [markdown]
# ## 2.5 Write your observations from the above.
# 1. Size of the dataset
# 2. What type of data attributes are there?
# 3. Is there any null data that has to be cleaned?
#
# Score: 2 Marks in total (0.25 marks for 2.1, 0.25 marks for 2.2, 0.5 marks for 2.3, 0.25 marks for 2.4, 0.75 marks for 2.5)

# %% [markdown]
# --------------Type the answers below this line--------------
# OBSERVATIONS
#
# 1. Size of the data set
#
#  (200,5)
#
# 2. What type of data attributes are there?
#
# Genre : is a Categorical column
#
#
# CustomerID : is a Numerical column
# Age : is a Numerical column
# Annual Income (k$) : is a Numerical column
# Spending Score (1-100) : is a Numerical column
#
# 3.Is there any null data that has to be cleaned?
#
# No.there are no missing values or null values in data set.

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# If input data is numerical or categorical, do 3.1, 3.2 and 3.4
# If input data is text, do 3.3 and 3.4

# %% [markdown]
# ## 3.1 Check for
#
# * duplicate data
# * missing data
# * data inconsistencies

# %%
##---------Type the code below this line------------------##
duplicateRows = df[df.duplicated()]
print(duplicateRows.index)

df.isnull().sum()
# Out:
# Int64Index([], dtype='int64')
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
def show_missing(df):
    """Return a Pandas dataframe describing the contents of a source dataframe including missing values."""
    
    variables = []
    dtypes = []
    count = []
    unique = []
    missing = []
    pc_missing = []
    
    for item in df.columns:
        variables.append(item)
        dtypes.append(df[item].dtype)
        count.append(len(df[item]))
        unique.append(len(df[item].unique()))
        missing.append(df[item].isna().sum())
        pc_missing.append(round((df[item].isna().sum() / len(df[item])) * 100, 2))

    output = pd.DataFrame({
        'variable': variables, 
        'dtype': dtypes,
        'count': count,
        'unique': unique,
        'missing': missing, 
        'pc_missing': pc_missing
    })    
        
    return output

# %%
show_missing(df)
# Out:
#                  variable   dtype  count  unique  missing  pc_missing
# 0              CustomerID   int64    200     200        0         0.0
# 1                   Genre  object    200       2        0         0.0
# 2                     Age   int64    200      51        0         0.0
# 3      Annual Income (k$)   int64    200      64        0         0.0
# 4  Spending Score (1-100)   int64    200      84        0         0.0

# %% [raw]
# --------------Type the answers below this line--------------
# No Duplicate
#
# Also there are no missing values or null values in data set.

# %% [markdown]
# ## 3.2 Apply techiniques
# * to remove duplicate data
# * to impute or remove missing data
# * to remove data inconsistencies

# %% [markdown]
# ##---------Type the code below this line------------------##
# No Duolicate data found in the dataset
# No missing data found in the dataset
# No data inconsistency found in the data

# %% [markdown]
# ## 3.3 Encode categorical data

# %%
##---------Type the code below this line------------------##
le = LabelEncoder()
df_enc=df.copy()
for col in df.columns:
    if df[col].dtype == 'object':
        df_enc[col] = le.fit_transform(df[col])

df_enc
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1      1   19                  15                      39
# 1             2      1   21                  15                      81
# 2             3      0   20                  16                       6
# 3             4      0   23                  16                      77
# 4             5      0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         196      0   35                 120                      79
# 196         197      0   45                 126                      28
# 197         198      1   32                 126                      74
# 198         199      1   32                 137                      18
# 199         200      1   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ## 3.4 Text data
#
# 1. Remove special characters
# 2. Change the case (up-casing and down-casing).
# 3. Tokenization — process of discretizing words within a document.
# 4. Filter Stop Words.

# %% [markdown]
# We don't have any text data in our dataset

# %%
##---------Type the code below this line------------------##

# %% [markdown]
# ## 3.4 Report
#
# Mention and justify the method adopted
# * to remove duplicate data, if present
# * to impute or remove missing data, if present
# * to remove data inconsistencies, if present
#
# OR for textdata
# * How many tokens after step 3?
# * how may tokens after stop words filtering?
#
# If the any of the above are not present, then also add in the report below.
#
# Score: 2 Marks (based on the dataset you have, the data prepreation you had to do and report typed, marks will be distributed between 3.1, 3.2, 3.3 and 3.4)

# %% [markdown]
# ##---------Type the code below this line------------------##
# Our dataset doesn't have any duplicate data, missing data or data inconsistencies

# %%
##---------Type the code below this line------------------##

# %% [markdown]
# ## 3.5 Identify the target variables.
#
# * Separate the data from the target such that the dataset is in the form of (X,y) or (Features, Label)
#
# * Discretize / Encode the target variable or perform one-hot encoding on the target or any other as and if required.
#
# * Report the observations
#
# Score: 1 Mark

# %%
## 3.5 Identify the target variables.

for col in df.columns:
    if (col == 'Spending Score (1-100)'):
        target_var = col
        print( 'The target variable is :#',target_var, '#')

##  Separate the data from the target such that the customer dataset in the form of (Features, Target)

Feature = df.iloc[:,:11].copy()
Label = df.iloc[:,12:].copy()
print('\nSize of the Feature data set is:',Feature.shape)
print('Size of the Lable data set is:',Label.shape)
# Out:
# The target variable is :# Spending Score (1-100) #
#
# Size of the Feature data set is: (200, 5)
# Size of the Lable data set is: (200, 0)

# %% [markdown]
# # 4. Data Exploration using various plots

# %% [markdown]
# ## 4.1 Scatter plot of each quantitative attribute with the target.
#
# Score: 1 Mark

# %%
##---------Type the code below this line------------------##
import matplotlib.pyplot as plt


# Set the figure size
plt.figure(figsize=(15, 5))

# Scatter plot of Age vs Spending Score
plt.subplot(1, 3, 1)
plt.scatter(df['Age'], df['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.title('Scatter plot of Age vs Spending Score')

# Scatter plot of Annual Income vs Spending Score
plt.subplot(1, 3, 2)
plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.title('Scatter plot of Annual Income vs Spending Score')

# Scatter plot of Genre vs Spending Score
plt.subplot(1, 3, 3)
plt.scatter(df['Genre'], df['Spending Score (1-100)'])
plt.xlabel('Genre')
plt.ylabel('Spending Score')
plt.title('Scatter plot of Genre vs Spending Score')

# Adjust the spacing between the plots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# OBSERVATIONS
#
# 1. The scatter plot of age vs spending score shows a clear negative correlation, indicating that younger customers tend to have  a higher spending score compared to older customers. As age increases, customers tend to spend less, possibly due to a decrease in disposable income or a shift in spending priorities
#
# 2. The scatter plot of annual income vs spending score does not show a very clear trend or pattern between the two variables. However, we can make some general observations based on the plot.There seems to be a cluster of customers with an annual income between 40-70 k$ who have a wide range of spending scores. Another cluster of customers with an annual income between 70-140 k$ seem to have a slightly higher average spending score. There is also a smaller cluster of customers with an annual income above 140 k$ who have a higher spending score
#
# 3. The scatter plot of genre vs spending score also does not show a clear trend or pattern.But there are roughly equal numbers of male and female customers in this dataset, and both groups have a wide range of spending scores. However, there is a slightly larger number of female customers with a higher spending score compared to male customers

# %% [markdown]
# ## 4.2 EDA using visuals
# * Use (minimum) 2 plots (pair plot, heat map, correlation plot, regression plot...) to identify the optimal set of attributes that can be used for classification.
# * Name them, explain why you think they can be helpful in the task and perform the plot as well. Unless proper justification for the choice of plots given, no credit will be awarded.
#
# Score: 2 Marks

# %%
##---------Type the code below this line------------------##
sns.heatmap(df.corr(), annot = True, cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df, hue="Genre")

# %% [markdown]
# OBSERVATIONS
# There is a weak negative correlation between age and spending score (-0.33).
# There is no significant correlation between annual income and age, or between annual income and spending score.
# There is a weak positive correlation between annual income and spending score (0.01)

# %% [markdown]
# # 5. Data Wrangling

# %% [markdown]
# ## 5.1 Univariate Filters
#
# #### Numerical and Categorical Data
# * Identify top 5 significant features by evaluating each feature independently with respect to the target variable by exploring
# 1. Mutual Information (Information Gain)
# 2. Gini index
# 3. Gain Ratio
# 4. Chi-Squared test
# 5. Fisher Score
# (From the above 5 you are required to use only any <b>two</b>)
#
# #### For Text data
#
# 1. Stemming / Lemmatization.
# 2. Forming n-grams and storing them in the document vector.
# 3. TF-IDF
# (From the above 2 you are required to use only any <b>two</b>)
#
#
# Score: 3 Marks

# %%
features = ["CustomerID","Age","Annual Income (k$)","Spending Score (1-100)"]

X_features = df_enc[features]
y_labels = df_enc["Annual Income (k$)"]

X_features.shape, y_labels.shape
# Out:
# ((200, 4), (200,))

# %%
X_features.head(2)
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   19                  15                      39
# 1           2   21                  15                      81

# %%
y_labels.value_counts()
# Out:
# 54     12
# 78     12
# 48      6
# 71      6
# 63      6
#        ..
# 58      2
# 59      2
# 16      2
# 64      2
# 137     2
# Name: Annual Income (k$), Length: 64, dtype: int64

# %%
##---------Type the code below this line------------------##
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest, mutual_info_classif


# Identify the target variable and the independent variables
target_var = 'Spending Score (1-100)'
independent_vars = [ "CustomerID","Age","Genre","Annual Income (k$)"]

# Chi-Squared test

# Calculate the chi-squared statistic and p-value for each independent variable
p_values = {}
for var in independent_vars:
    contingency_table = pd.crosstab(df_enc[var], df_enc[target_var])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    p_values[var] = p

# Sort the p-values in ascending order and select the top 5 features
top_features = sorted(p_values, key=p_values.get)[:5]

# Print the top 5 features with their p-values
for feature in top_features:
    print('Chi-Squared test : ',feature, p_values[feature])
    
    
   # fisher_score 
    

# Use SelectKBest with fisher_score to select top 5 features
X = df_enc[independent_vars]
y = df_enc[target_var]
selector = SelectKBest(score_func=f_classif, k=4)
selector.fit(X, y)

# Print the top 4 features
top_features = X.columns[selector.get_support(indices=True)].tolist()
print('fisher_score :  ',top_features)
# Out:
# Chi-Squared test :  Age 0.19539889566453184
# Chi-Squared test :  CustomerID 0.3229129721955616
# Chi-Squared test :  Annual Income (k$) 0.33734866404489705
# Chi-Squared test :  Genre 0.34123996771002013
# fisher_score :   ['CustomerID', 'Age', 'Genre', 'Annual Income (k$)']

# %% [markdown]
# ## 5.2 Report observations
#
# Write your observations from the results of each method. Clearly justify your choice of the method.
#
# Score 1 mark

# %% [markdown]
# OBSERVATIONS
#
# 1. Chi-Squared test suggests that none of the independent variables are significantly associated with the target variable
#
# 2. Fisher score indicates that all the independent variables are important in predicting the target variable
#
# 3. Require further investigation to determine the actual relationship between the independent variables and the target variable

# %% [markdown]
# # 6. Implement Machine Learning Techniques
#
# Use any 2 ML algorithms
# 1. Classification -- Decision Tree classifier
#
# 2. Clustering -- kmeans
#
# 3. Association Analysis
#
# 4. Anomaly detection
#
# 5. Textual data -- Naive Bayes classifier (not taught in this course)
#
# A clear justification have to be given for why a certain algorithm was chosen to address your problem.
#
# Score: 4 Marks (2 marks each for each algorithm)

# %% [markdown]
#  6.1 ML technique 1 + Justification

# %%
from sklearn.preprocessing import LabelEncoder, PowerTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

X = df_enc.drop(['CustomerID', 'Spending Score (1-100)'], axis=1)
y = df_enc['Spending Score (1-100)']

# Normalize the data using PowerTransformer
pt = PowerTransformer(method='yeo-johnson')
X = pd.DataFrame(pt.fit_transform(X), columns=X.columns)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# Create a decision tree classifier
clf = DecisionTreeClassifier()

# Fit the classifier to the training data
clf.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = clf.predict(X_test)

# Print classification report and confusion matrix
print('****************** Decision Tree Classification ****************')
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion matrix')
plt.show()
# Out:
# ****************** Decision Tree Classification ****************
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         1
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         2
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         1
#           16       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         1
# ...

# %% [markdown]
# OBSERVATIONS
#
# The classifier is performing better at identifying instances with a low spending score than those with a high spending score, as indicated by the higher number of true positives for class 0. However, the classifier is still making a considerable number of errors, especially in predicting instances with a high spending score

# %% [markdown]
# ## 6.2 ML technique 2 + Justification

# %%
##---------Type the code below this line------------------##    
from sklearn.cluster import KMeans

X = df[["CustomerID",'Age','Annual Income (k$)','Spending Score (1-100)']]
                      
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.scatter(X.loc[:, 'Annual Income (k$)'], X.loc[:, 'Spending Score (1-100)'], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score
silhouette_avg = silhouette_score(X, y_kmeans)

# Print the silhouette score
print("The average silhouette score is :", silhouette_avg)
# Out:
# The average silhouette score is : 0.37674423270868146

# %% [markdown]
# OBSERVATIONS
#
# Clustering using KMeans algorithm and visualizes the clusters. Clustering is an unsupervised learning task, and therefore metrics like accuracy, precision, recall, F1 Score, AUC-ROC are not applicable here
#
# The average silhouette score of 0.3767 indicates that the clustering algorithm has produced relatively well-separated clusters, but there may be some overlap between clusters

# %% [markdown]
# ## 7. Conclusion
#
# Compare the performance of the ML techniques used.
#
# Derive values for preformance study metrics like accuracy, precision, recall, F1 Score, AUC-ROC etc to compare the ML algos and plot them. A proper comparision based on different metrics should be done and not just accuracy alone, only then the comparision becomes authentic. You may use Confusion matrix, classification report, Word cloud etc as per the requirement of your application/problem.
#
# Score 1 Mark

# %% [markdown]
# ##---------Type the code below this line------------------##
#
# We have used Decision tree classifier & K means clustering techniques to learn the buying behaviour of the customer.
#
# Decision tree classifer is performing better at low spending score, but high number of errors when the spending score increases.
#
# On the other hand, the Kmeans clustering, even though its an unsupervised learning task, it produced a relatively well separated cluster.
# Silhouette score of 0.3767

# %% [markdown]
# ## 8. Solution
#
# What is the solution that is proposed to solve the business problem discussed in Section 1. Also share your learnings while working through solving the problem in terms of challenges, observations, decisions made etc.
#
# Score 2 Marks

# %% [markdown]
# --------------Type the answers below this line--------------

# %% [markdown]
# ##---------Type the answer below this line------------------##
#
# We have identified the different clusters/segments of customers visiting the mall.
# Mall management can target the clusters with average spending score to increase their profit and should also maintain good relationship with premium customers with high spending score.They should also work on coming up with new innovative ideas to upgrade the customers with low spending score.
#
# Observations : Almost all the clusters have similar density. It is also fast and efficient in terms of computational cost.
#
# Challenges : More details regarding the demography of the customers like employment type, time spent at mall, etc. required to find correlation of other factors on the spending of customers other than annual income
#
# Learnings :
#
# >>By enabling companies to target specific groups of customers, a customer segmentation model allows for the effective allocation of marketing resources and the maximization of cross- and up-selling opportunities.
# >>When a group of customers is sent personalized messages as part of a marketing mix that is designed around their needs, it's easier for companies to send those customers special offers meant to encourage them to buy more products. Customer segmentation can also improve customer service and assist in customer loyalty and retention.
#
# >>As a by-product of its personalized nature, marketing materials sent out using customer segmentation tend to be more valued and appreciated by the customer who receives them as opposed to impersonal brand messaging that doesn't acknowledge purchase history or any kind of customer relationship.
#
# >> Other benefits of customer segmentation include staying a step ahead of competitors in specific sections of the market and identifying new products that existing or potential customers could be interested in or improving products to meet customer expectations.

# %% [markdown]
# ##NOTE
# All Late Submissions will incur a penalty of -2 marks. Do ensure on time submission to avoid penalty.
#
# Good Luck!!!
